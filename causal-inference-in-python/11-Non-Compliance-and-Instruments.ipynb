# %% [markdown]
# # 11 Non-Compliance and Instruments

# %%
from toolz.curried import *

import pandas as pd
import numpy as np
from scipy.special import expit

import statsmodels.formula.api as smf

import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib


from cycler import cycler

color=['0.0', '0.4', '0.8']
default_cycler = (cycler(color=color))
linestyle=['-', '--', ':', '-.']
marker=['o', 'v', 'd', 'p']

plt.rc('axes', prop_cycle=default_cycler)

# %% [markdown]
# ## Non-Compliance

# %%
from graphviz import Digraph

gr = Digraph(format="png", graph_attr={"rankdir":"LR"})

gr.edge("U", "T")
gr.edge("U", "Y")
gr.edge("Z", "T")
gr.edge("T", "Y")

gr

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("./data/prime_card.csv")

df.head()
# Out:
#     age   income  credit_score  prime_elegible  prime_card       pv    tau  \
# 0  37.7   9687.0         822.0               0           0  4913.79  700.0
# 1  46.0  13731.0         190.0               0           0  5637.66  200.0
# 2  43.1   2839.0         214.0               1           1  2410.45  700.0
# 3  36.0   1206.0         318.0               1           1  1363.06  700.0
# 4  39.7   4095.0         430.0               0           0  2189.80  700.0
#
#          categ
# 0     complier
# 1  never-taker
# 2     complier
# 3     complier
# 4     complier

# %% [markdown]
# ## Extending Potential Outcomes

# %%
m = smf.ols("pv~prime_elegible", data=df).fit()
m.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
df["tau"].mean()
# Out:
# 413.45

# %%
m = smf.ols("pv~prime_card", data=df).fit()
m.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Instrument Identification Assumptions

# %% [markdown]
# ## First Stage

# %%
first_stage = smf.ols("prime_card ~ prime_elegible", data=df).fit()
first_stage.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
df.groupby("categ").size()/len(df)
# Out:
# categ
# complier       0.4269
# never-taker    0.5731
# dtype: float64

# %% [markdown]
# ## Reduced Form

# %%
red_form = smf.ols("pv ~ prime_elegible", data=df).fit()
red_form.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
late = (red_form.params["prime_elegible"] /
        first_stage.params["prime_elegible"])
late
# Out:
# 757.6973795343963

# %%
df.groupby("categ")["tau"].mean()
# Out:
# categ
# complier       700.0
# never-taker    200.0
# Name: tau, dtype: float64

# %% [markdown]
# ## Two Stage Least Squares

# %%
gr = Digraph(format="png", graph_attr={"rankdir":"LR"})

gr.edge("U", "T")
gr.edge("U", "Y")
gr.edge("Z", "T")
gr

# %%
iv_regr = smf.ols(
    "pv ~ prime_card",
    data=df.assign(prime_card=first_stage.fittedvalues)).fit()

iv_regr.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Standard Error

# %%
Z = df["prime_elegible"]
T = df["prime_card"]
n = len(df)

# not the same as iv_regr.resid!
e_iv = df["pv"] - iv_regr.predict(df)
compliance = np.cov(T, Z)[0, 1]/Z.var()

se = np.std(e_iv)/(compliance*np.std(Z)*np.sqrt(n))

print("SE IV:", se)
print("95% CI:", [late - 2*se, late + 2*se])
# Out:
# SE IV: 80.5286102614194
# 95% CI: [596.6401590115574, 918.7546000572352]

# %%
from linearmodels import IV2SLS

formula = 'pv ~ 1 + [prime_card ~ prime_elegible]'
iv_model = IV2SLS.from_formula(formula, df).fit(cov_type="unadjusted")

iv_model.summary.tables[1]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 from linearmodels import IV2SLS
#       3 formula = 'pv ~ 1 + [prime_card ~ prime_elegible]'
#       4 iv_model = IV2SLS.from_formula(formula, df).fit(cov_type="unadjusted")
#
# ModuleNotFoundError: No module named 'linearmodels'

# %%
# !{sys.executable} -m pip install linearmodels --upgrade
# Out:
# Collecting linearmodels
#   Downloading linearmodels-4.31-cp38-cp38-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.16 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from linearmodels) (1.24.4)
# Requirement already satisfied: pandas>=0.24 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from linearmodels) (2.0.3)
# Requirement already satisfied: scipy>=1.2 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from linearmodels) (1.10.1)
# Requirement already satisfied: statsmodels>=0.11 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from linearmodels) (0.14.1)
# Collecting property-cached>=1.6.3 (from linearmodels)
#   Downloading property_cached-1.6.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting mypy-extensions>=0.4 (from linearmodels)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: Cython>=0.29.21 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from linearmodels) (3.0.12)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Using cached pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=0.3.2 (from linearmodels)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting setuptools-scm>=7.0.0 (from setuptools-scm[toml]>=7.0.0->linearmodels)
#   Downloading setuptools_scm-9.2.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting astor>=0.8 (from formulaic>=0.3.2->linearmodels)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting graphlib-backport>=1.0.0 (from formulaic>=0.3.2->linearmodels)
#   Downloading graphlib_backport-1.1.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.3.2->linearmodels)
#   Using cached interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from formulaic>=0.3.2->linearmodels) (4.5.0)
# Requirement already satisfied: wrapt>=1.0 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from formulaic>=0.3.2->linearmodels) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from pandas>=0.24->linearmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from pandas>=0.24->linearmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from pandas>=0.24->linearmodels) (2025.1)
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from setuptools-scm>=7.0.0->setuptools-scm[toml]>=7.0.0->linearmodels) (24.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from setuptools-scm>=7.0.0->setuptools-scm[toml]>=7.0.0->linearmodels) (75.3.0)
# Collecting tomli>=1 (from setuptools-scm>=7.0.0->setuptools-scm[toml]>=7.0.0->linearmodels)
#   Downloading tomli-2.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: patsy>=0.5.4 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from statsmodels>=0.11->linearmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/taskb_env_py38/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=0.24->linearmodels) (1.17.0)
# Downloading linearmodels-4.31-cp38-cp38-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.2 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Using cached pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading setuptools_scm-9.2.2-py3-none-any.whl (62 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading graphlib_backport-1.1.0-py3-none-any.whl (7.1 kB)
# Using cached interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: tomli, property-cached, mypy-extensions, interface-meta, graphlib-backport, astor, setuptools-scm, pyhdfe, formulaic, linearmodels
# Successfully installed astor-0.8.1 formulaic-1.1.1 graphlib-backport-1.1.0 interface-meta-1.3.0 linearmodels-4.31 mypy-extensions-1.1.0 property-cached-1.6.4 pyhdfe-0.2.0 setuptools-scm-9.2.2 tomli-2.3.0

# %%
se_formula_iv = lambda compliance: np.std(e_iv)/(compliance*np.std(Z)*np.sqrt(n))
x = np.linspace(0.01, 1, 50)

effect = iv_regr.params["prime_card"]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(x, effect-se_formula_iv(x)*2, label="SE($\\beta_{IV}$) x2", ls=":", color="0")
ax1.plot(x, effect+se_formula_iv(x)*2, ls=":", color="0")
ax1.hlines(effect, 0, 1, ls="-.", label="LATE")
ax1.hlines(0, 0, 1)
ax1.set_xlabel("Compliance")
ax1.set_ylim(-(effect+100), (effect+100)*2)
ax1.legend(loc="lower right")
ax1.set_title("95% CI around LATE");


x = np.linspace(0.2, 1, 50)
ax2.plot(x, 1/(x**2))
ax2.hlines(10, 0.2, 1, ls=":", label="10")
ax2.hlines(4, 0.2, 1, ls="-.", label="4")
ax2.set_xlabel("Compliance")
ax2.set_ylabel("$N_{IV}$/N")
ax2.set_title("Required Sample Size Ratio")
ax2.legend()

# %% [markdown]
# ## Additional Controls and Instruments

# %%
gr = Digraph(format="png", graph_attr={"rankdir":"LR"})

gr.edge("U", "T")
gr.edge("U", "Y")
gr.edge("Z", "T")
gr.edge("T", "Y")
gr.edge("Income", "Y")
gr.edge("Age", "T")
gr.edge("Age", "Y")
gr.edge("Score", "T")

gr

# %%
formula = 'pv ~ 1 + [prime_card ~ prime_elegible + credit_score]'
iv_model = IV2SLS.from_formula(formula, df).fit()

iv_model.summary.tables[1]

# %%
formula = '''pv ~ 1 
+ [prime_card ~ prime_elegible + credit_score]
+ income + age'''

iv_model = IV2SLS.from_formula(formula, df).fit(cov_type="unadjusted")

iv_model.summary.tables[1]

# %% [markdown]
# ### 2SLS by Hand

# %%
formula_1st = "prime_card ~ prime_elegible + credit_score + income+age"
first_stage = smf.ols(formula_1st, data=df).fit()

iv_model = smf.ols(
    "pv ~ prime_card + income + age",
    data=df.assign(prime_card=first_stage.fittedvalues)).fit()

iv_model.summary().tables[1]

# %% [markdown]
# ### Matrix Implementation

# %%
Z = df[["prime_elegible", "credit_score", "income", "age"]].values
X = df[["prime_card", "income", "age"]].values
Y = df[["pv"]].values

def add_intercept(x):
    return np.concatenate([np.ones((x.shape[0], 1)), x], axis=1)

Z_ = add_intercept(Z)
X_ = add_intercept(X)

# pre-multiplying Z_.dot(...) last is important to avoid
# creating a huge NxN matrix
X_hat = Z_.dot(np.linalg.inv(Z_.T.dot(Z_)).dot(Z_.T).dot(X_))

b_iv = np.linalg.inv(X_hat.T.dot(X_hat)).dot(X_hat.T).dot(Y)
b_iv[1]

# %%
e_hat_iv = (Y - X_.dot(b_iv))

var = e_hat_iv.var()*np.diag(np.linalg.inv(X_hat.T.dot(X_hat)))

np.sqrt(var[1])

# %%
t_tilde = smf.ols("prime_card ~ income + age", data=df).fit().resid

e_hat_iv.std()/(t_tilde.std()*np.sqrt(n*first_stage.rsquared))

# %% [markdown]
# ## Discontinuity Design

# %% [markdown]
# ### Discontinuity Design Assumptions

# %% [markdown]
# ### Intention to Treat Effect

# %%
df_dd = pd.read_csv("./data/prime_card_discontinuity.csv")
df_dd.head()

# %%
m = smf.ols(f"pv~balance*I(balance>0)",
            df_dd.assign(balance = lambda d: d["balance"] - 5000)).fit()
m.summary().tables[1]

# %%
plt_df = df_dd.round({"balance": -2}).assign(size=1).groupby("balance").agg({"pv":"mean", "size": "sum"}).reset_index()

plt.figure(figsize=(8,4))
sns.scatterplot(data=plt_df, y="pv", x="balance", size="size", color="C5")
plt.plot(plt_df.query("balance<5000")["balance"], m.predict(plt_df.query("balance<5000").assign(balance = lambda d: d["balance"] - 5000)), color="C0", lw=2, label="regression")
plt.plot(plt_df.query("balance>5000")["balance"], m.predict(plt_df.query("balance>5000").assign(balance = lambda d: d["balance"] - 5000)), color="C0", lw=2)
plt.legend(fontsize=14)

# %% [markdown]
# ### The IV Estimate
#
# Errata: The book does not center the discontinuity at zero. Therefore, the intercept for the ITTE regression cannot be interpreted as the ITTE. Here, I'm centering the discontinuity at zero.

# %%
def rdd_iv(data, y, t, r, cutoff):
    
    centered_df = data.assign(**{r: data[r]-cutoff})
    
    compliance = smf.ols(f"{t}~{r}*I({r}>0)", centered_df).fit()
    itte = smf.ols(f"{y}~{r}*I({r}>0)", centered_df).fit()
    
    param = f"I({r} > 0)[T.True]"
    return itte.params[param]/compliance.params[param]


rdd_iv(df_dd, y="pv", t="prime_card", r="balance", cutoff=5000)

# %%
(df_dd
 .round({"balance":-2}) # round to nearest hundred
 .query("balance==5000 & categ=='complier'")["tau"].mean())

# %%
from joblib import Parallel, delayed
from toolz import partial

def bootstrap(data, est_fn, rounds=200, seed=123, pcts=[2.5, 97.5]):
    np.random.seed(seed)
    
    stats = Parallel(n_jobs=4)(
        delayed(est_fn)(data.sample(frac=1, replace=True))
        for _ in range(rounds)
    )
    
    return np.percentile(stats, pcts)


bootstrap(df_dd,
          partial(rdd_iv, y="pv", t="prime_card", r="balance", cutoff=5000))

# %% [markdown]
# ### Bunching

# %%
plt.figure(figsize=(10,4))
df_dd.round({"balance":-3}).groupby("balance").size().plot.bar()
plt.ylabel("Sample Size.")
plt.xlabel("Balance (rounded to nearest 1000)")

# %% [markdown]
# ## Key Ideas

# %%
gr = Digraph(format="png", graph_attr={"rankdir":"LR"})

gr.edge("U", "School")
gr.edge("U", "Income")
gr.edge("Quarter", "School")
gr.edge("School", "Income")
gr
